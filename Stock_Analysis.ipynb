# %%
import pandas as pd
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20352\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib.pyplot
# !pip install seaborn
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# ...

# %%
# !pip install glob
# Out:
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
import glob

# %%
glob.glob(r'F:\Data Science\Data Analytics Projects\Stock\individual_stocks_5yr/*csv')
# Out:
# ['F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\AAL_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\AAPL_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\AAP_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ABBV_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ABC_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ABT_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ACN_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ADBE_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ADI_data.csv',
#  'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\ADM_data.csv',
# ...

# %%
len(glob.glob(r'F:\Data Science\Data Analytics Projects\Stock\individual_stocks_5yr/*csv'))
# Out:
# 509

# %%
company_list =[
    r'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\AAPL_data.csv',
    r'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\AMZN_data.csv',
    r'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\GOOG_data.csv',
    r'F:\\Data Science\\Data Analytics Projects\\Stock\\individual_stocks_5yr\\MSFT_data.csv'
]

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
all_data = pd.DataFrame()

for file in company_list:
    
    current_df = pd.read_csv(file)
    
    all_data = current_df._append(all_data , ignore_index=True)

# %%
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.head(6)
# Out:
#          date   open   high     low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.310  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.500  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.750  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.880  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.870  28.04  32663174  MSFT
# 5  2013-02-15  28.04  28.16  27.875  28.01  49650538  MSFT

# %%
all_data['Name'].unique()
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
all_data.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data['date'] =pd.to_datetime(all_data['date'])

# %%
all_data['date']
# Out:
# 0      2013-02-08
# 1      2013-02-11
# 2      2013-02-12
# 3      2013-02-13
# 4      2013-02-14
#           ...
# 4747   2018-02-01
# 4748   2018-02-02
# 4749   2018-02-05
# 4750   2018-02-06
# 4751   2018-02-07
# Name: date, Length: 4752, dtype: datetime64[ns]

# %%
tech_list = all_data['Name'].unique()

# %%
tech_list
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 ,2 , index)
    filter1 = all_data['Name']==company
    df= all_data[filter1]
    plt.plot(df['date'] , df['close']) ## plotting "date" vs "close"
    plt.title(company)

# %%
all_data.head(15)
# Out:
#          date     open   high     low   close    volume  Name
# 0  2013-02-08  27.3500  27.71  27.310  27.550  33318306  MSFT
# 1  2013-02-11  27.6500  27.92  27.500  27.860  32247549  MSFT
# 2  2013-02-12  27.8800  28.00  27.750  27.880  35990829  MSFT
# 3  2013-02-13  27.9300  28.11  27.880  28.030  41715530  MSFT
# 4  2013-02-14  27.9200  28.06  27.870  28.040  32663174  MSFT
# 5  2013-02-15  28.0400  28.16  27.875  28.010  49650538  MSFT
# 6  2013-02-19  27.8801  28.09  27.800  28.045  38804616  MSFT
# 7  2013-02-20  28.1300  28.20  27.830  27.870  44109412  MSFT
# 8  2013-02-21  27.7400  27.74  27.230  27.490  49078338  MSFT
# 9  2013-02-22  27.6800  27.76  27.480  27.760  31425726  MSFT
# 10 2013-02-25  27.9700  28.05  27.370  27.370  48011248  MSFT
# 11 2013-02-26  27.3800  27.60  27.340  27.370  49917353  MSFT
# 12 2013-02-27  27.4200  28.00  27.330  27.810  36390889  MSFT
# 13 2013-02-28  27.8800  27.97  27.740  27.800  35836861  MSFT
# ...

# %%
all_data['close'].rolling(window=10).mean().head(14)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     27.8535
# 10    27.8355
# 11    27.7865
# 12    27.7795
# 13    27.7565
# Name: close, dtype: float64

# %%
new_data =all_data.copy()

# %%
ma_data = [10 ,20 , 50]

for ma in ma_data:
    new_data['close'+str(ma)] = new_data['close'].rolling(ma).mean()

# %%
new_data.set_index('date' ,inplace=True)

# %%
new_data
# Out:
#                open    high       low   close    volume  Name  close10  \
# date
# 2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT      NaN
# 2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT      NaN
# 2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT      NaN
# 2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT      NaN
# 2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT      NaN
# ...             ...     ...       ...     ...       ...   ...      ...
# 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL  171.948
# 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL  170.152
# 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL  168.101
# 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL  166.700
# 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL  165.232
#
#              close20   close50
# date
# 2013-02-08       NaN       NaN
# 2013-02-11       NaN       NaN
# ...

# %%
new_data.tail(10)
# Out:
#                open      high       low   close    volume  Name  close10  \
# date
# 2018-01-25  174.505  174.9500  170.5300  171.11  41529004  AAPL  176.475
# 2018-01-26  172.000  172.0000  170.0600  171.51  39143011  AAPL  176.098
# 2018-01-29  170.160  170.1600  167.0700  167.96  50640406  AAPL  175.185
# 2018-01-30  165.525  167.3700  164.7000  166.97  46048185  AAPL  174.263
# 2018-01-31  166.870  168.4417  166.5000  167.43  32478930  AAPL  173.096
# 2018-02-01  167.165  168.6200  166.7600  167.78  47230787  AAPL  171.948
# 2018-02-02  166.000  166.8000  160.1000  160.50  86593825  AAPL  170.152
# 2018-02-05  159.100  163.8800  156.0000  156.49  72738522  AAPL  168.101
# 2018-02-06  154.830  163.7200  154.0000  163.03  68243838  AAPL  166.700
# 2018-02-07  163.085  163.4000  159.0685  159.54  51608580  AAPL  165.232
#
#              close20   close50
# date
# 2018-01-25  174.5575  173.1050
# 2018-01-26  174.6030  173.0558
# 2018-01-29  174.4470  172.9882
# ...

# %%
new_data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'Name', 'close10', 'close20',
#        'close50'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index)
    filter1 = new_data['Name']==company
    df = new_data[filter1]
    df[['close_10','close_20', 'close_50']].plot(ax=plt.gca())
    plt.title(company)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 7
#       5 filter1 = new_data['Name']==company
#       6 df = new_data[filter1]
# ----> 7 df[['close_10','close_20', 'close_50']].plot(ax=plt.gca())
#       8 plt.title(company)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
company_list
# Out:
# ['F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AAPL_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AMZN_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\GOOG_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\MSFT_data.csv']

# %%
apple =pd.read_csv(r'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AAPL_data.csv')

# %%
apple.head(5)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
apple['close']
# Out:
# 0        67.8542
# 1        68.5614
# 2        66.8428
# 3        66.7156
# 4        66.6556
#           ...
# 1254    167.7800
# 1255    160.5000
# 1256    156.4900
# 1257    163.0300
# 1258    159.5400
# Name: close, Length: 1259, dtype: float64

# %%
apple.head(5)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
apple.head(5)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
apple['Daily return(in %)'] = apple['close'].pct_change() * 100

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#    Daily return(in %)
# 0                 NaN
# 1            1.042235
# 2           -2.506658
# 3           -0.190297

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
px.line(apple , x="date" , y="Daily return(in %)") ## Plotting Line-plot of "date" vs "Daily return(in %)"..

# %%
apple.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily return(in %)    float64
# dtype: object

# %%
apple['date'] =pd.to_datetime(apple['date'])

# %%
apple.dtypes
# Out:
# date                  datetime64[ns]
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# volume                         int64
# Name                          object
# Daily return(in %)           float64
# dtype: object

# %%
apple.head(4)
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#    Daily return(in %)
# 0                 NaN
# 1            1.042235
# 2           -2.506658
# 3           -0.190297

# %%
apple.set_index('date' , inplace=True)

# %%
apple.head(4)
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#             Daily return(in %)
# date
# 2013-02-08                 NaN
# 2013-02-11            1.042235
# 2013-02-12           -2.506658
# 2013-02-13           -0.190297

# %%
apple['close'].resample('M').mean() ## resamp
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: ME, Name: close, Length: 61, dtype: float64

# %%
apple['close'].resample('M').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple['close'].resample('Y').mean() ## resample data on Yearly basis ..
# Out:
# date
# 2013-12-31     67.237839
# 2014-12-31     92.264531
# 2015-12-31    120.039861
# 2016-12-31    104.604008
# 2017-12-31    150.585080
# 2018-12-31    171.594231
# Freq: YE-DEC, Name: close, dtype: float64

# %%
apple['close'].resample('Y').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
apple['close'].resample('Q').mean() ## resample data on Quarterly basis ..
# Out:
# date
# 2013-03-31     64.020291
# 2013-06-30     61.534692
# 2013-09-30     66.320670
# 2013-12-31     75.567478
# 2014-03-31     76.086293
# 2014-06-30     85.117475
# 2014-09-30     98.163311
# 2014-12-31    108.821016
# 2015-03-31    120.776721
# 2015-06-30    127.937937
# 2015-09-30    117.303438
# 2015-12-31    114.299297
# 2016-03-31     99.655082
# 2016-06-30     99.401250
# 2016-09-30    105.866094
# 2016-12-31    113.399048
# 2017-03-31    131.712500
# 2017-06-30    147.875397
# 2017-09-30    155.304603
# 2017-12-31    167.148254
# 2018-03-31    171.594231
# Freq: QE-DEC, Name: close, dtype: float64

# %%
apple['close'].resample('Q').mean().plot()
# Out:
# <Axes: xlabel='date'>

# %%
company_list
# Out:
# ['F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AAPL_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AMZN_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\GOOG_data.csv',
#  'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\MSFT_data.csv']

# %%
company_list[0]
# Out:
# 'F:\\\\Data Science\\\\Data Analytics Projects\\\\Stock\\\\individual_stocks_5yr\\\\AAPL_data.csv'

# %%
app = pd.read_csv(company_list[0])
amzn = pd.read_csv(company_list[1])
google = pd.read_csv(company_list[2])
msft = pd.read_csv(company_list[3])

# %%
closing_price = pd.DataFrame()

# %%
closing_price['apple_close']=app['close']
closing_price['amazon_price'] =amzn['close']
closing_price['google_price']=google['close']
closing_price['microsoft_price']=msft['close']

# %%
closing_price
# Out:
#       apple_close  amazon_price  google_price  microsoft_price
# 0         67.8542        261.95        558.46            27.55
# 1         68.5614        257.21        559.99            27.86
# 2         66.8428        258.70        556.97            27.88
# 3         66.7156        269.47        567.16            28.03
# 4         66.6556        269.24        567.00            28.04
# ...           ...           ...           ...              ...
# 1254     167.7800       1390.00           NaN            94.26
# 1255     160.5000       1429.95           NaN            91.78
# 1256     156.4900       1390.00           NaN            88.00
# 1257     163.0300       1442.84           NaN            91.33
# 1258     159.5400       1416.78           NaN            89.61
#
# [1259 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(closing_price)

# %%
closing_price.corr()
# Out:
#                  apple_close  amazon_price  google_price  microsoft_price
# apple_close         1.000000      0.819078      0.640522         0.899689
# amazon_price        0.819078      1.000000      0.888456         0.955977
# google_price        0.640522      0.888456      1.000000         0.907011
# microsoft_price     0.899689      0.955977      0.907011         1.000000

# %%
sns.heatmap(closing_price.corr() , annot =  True)
# Out:
# <Axes: >

# %%
closing_price
# Out:
#       apple_close  amazon_price  google_price  microsoft_price
# 0         67.8542        261.95        558.46            27.55
# 1         68.5614        257.21        559.99            27.86
# 2         66.8428        258.70        556.97            27.88
# 3         66.7156        269.47        567.16            28.03
# 4         66.6556        269.24        567.00            28.04
# ...           ...           ...           ...              ...
# 1254     167.7800       1390.00           NaN            94.26
# 1255     160.5000       1429.95           NaN            91.78
# 1256     156.4900       1390.00           NaN            88.00
# 1257     163.0300       1442.84           NaN            91.33
# 1258     159.5400       1416.78           NaN            89.61
#
# [1259 rows x 4 columns]

# %%
closing_price['apple_close']
# Out:
# 0        67.8542
# 1        68.5614
# 2        66.8428
# 3        66.7156
# 4        66.6556
#           ...
# 1254    167.7800
# 1255    160.5000
# 1256    156.4900
# 1257    163.0300
# 1258    159.5400
# Name: apple_close, Length: 1259, dtype: float64

# %%
closing_price['apple_close'].shift(1)
# Out:
# 0            NaN
# 1        67.8542
# 2        68.5614
# 3        66.8428
# 4        66.7156
#           ...
# 1254    167.4300
# 1255    167.7800
# 1256    160.5000
# 1257    156.4900
# 1258    163.0300
# Name: apple_close, Length: 1259, dtype: float64

# %%
(closing_price['apple_close']-closing_price['apple_close'].shift(1))/closing_price['apple_close'].shift(1) *100
# Out:
# 0            NaN
# 1       1.042235
# 2      -2.506658
# 3      -0.190297
# 4      -0.089934
#           ...
# 1254    0.209043
# 1255   -4.339015
# 1256   -2.498442
# 1257    4.179181
# 1258   -2.140710
# Name: apple_close, Length: 1259, dtype: float64

# %%
for col in closing_price.columns:
    closing_price[col + '_pct_change'] = (closing_price[col] - closing_price[col].shift(1))/closing_price[col].shift(1) * 100

# %%
closing_price.columns
# Out:
# Index(['apple_close', 'amazon_price', 'google_price', 'microsoft_price',
#        'apple_close_pct_change', 'amazon_price_pct_change',
#        'google_price_pct_change', 'microsoft_price_pct_change'],
#       dtype='object')

# %%
closing_price
# Out:
#       apple_close  amazon_price  google_price  microsoft_price  \
# 0         67.8542        261.95        558.46            27.55
# 1         68.5614        257.21        559.99            27.86
# 2         66.8428        258.70        556.97            27.88
# 3         66.7156        269.47        567.16            28.03
# 4         66.6556        269.24        567.00            28.04
# ...           ...           ...           ...              ...
# 1254     167.7800       1390.00           NaN            94.26
# 1255     160.5000       1429.95           NaN            91.78
# 1256     156.4900       1390.00           NaN            88.00
# 1257     163.0300       1442.84           NaN            91.33
# 1258     159.5400       1416.78           NaN            89.61
#
#       apple_close_pct_change  amazon_price_pct_change  \
# 0                        NaN                      NaN
# 1                   1.042235                -1.809506
# ...

# %%
clsing_p = closing_price[['apple_close_pct_change', 'amazon_price_pct_change',
       'google_price_pct_change', 'microsoft_price_pct_change']]

# %%
clsing_p
# Out:
#       apple_close_pct_change  amazon_price_pct_change  \
# 0                        NaN                      NaN
# 1                   1.042235                -1.809506
# 2                  -2.506658                 0.579293
# 3                  -0.190297                 4.163123
# 4                  -0.089934                -0.085353
# ...                      ...                      ...
# 1254                0.209043                -4.196734
# 1255               -4.339015                 2.874101
# 1256               -2.498442                -2.793804
# 1257                4.179181                 3.801439
# 1258               -2.140710                -1.806160
#
#       google_price_pct_change  microsoft_price_pct_change
# 0                         NaN                         NaN
# 1                    0.273968                    1.125227
# 2                   -0.539295                    0.071788
# 3                    1.829542                    0.538020
# ...

# %%
g = sns.PairGrid(data= clsing_p)
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)
